# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import scipy.stats as stats

# %% [markdown]
# The following data is from a Kaggle competition to most accurately predict housing prices in Ames, Iowa, compiled by Dean De Cook.  I chose this dataset because it's practical and can be used by house sellers or buyers alike.  The following Jupyter notebook illustrates my process from data exploration to feature enginerring to finally, modeling.

# %%
raw_data = pd.read_csv(r'C:\Users\chase\Anaconda3\Database_Dictionary\Kaggle\House_Prices\train.csv')
raw_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# Our dependant variable here is the SalePrice.  First we need to check SalePrice distribution, as linear models like normally distributed data.

# %%
raw_data.shape
# Out:
# (1451, 65)

# %%
hist = sns.distplot(raw_data['SalePrice'])
plt.title('Sale Price Histogram')
plt.ylabel('Counts')
plt.xlabel("Sale Price")
plt.show()
# Out:
# C:\Users\chase\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
res = stats.probplot(raw_data['SalePrice'], plot=plt)
plt.show()

# %% [markdown]
# Our dependant variable is right skewed, so we therefore need to transform it to try to get it more normally distributed.  Let's try a log transformation.

# %%
raw_data['logSalePrice'] = raw_data['SalePrice'].apply(np.log)
hist = sns.distplot(raw_data['logSalePrice'])
plt.title('log Sale Price Histogram')
plt.ylabel('Counts')
plt.xlabel("log Sale Price")
plt.show()
# Out:
# C:\Users\chase\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
res = stats.probplot(raw_data['logSalePrice'], plot=plt)
plt.show()

# %% [markdown]
# This looks better.  The transformed Sale Price is more normally distributed and should work better in our models.  Let's describe our outcome variable to make sure there isn't anything crazy going on.

# %%
raw_data['logSalePrice'].describe()
# Out:
# count    1460.000000
# mean       12.024051
# std         0.399452
# min        10.460242
# 25%        11.775097
# 50%        12.001505
# 75%        12.273731
# max        13.534473
# Name: logSalePrice, dtype: float64

# %%
raw_data['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# Nope the data doesn't look abnormal, such as extra zeroes on our max or a negative min.  Our next step will evaluating our features for feature selection.  I first like to look over and see if any features don't make sense in the model.  I then like to look for colinearity which can skew our results as well.  Remember, regression models do not like multicollinearity.  The seaborn heatmap is great for this.

# %%
f, ax = plt.subplots(figsize=(12, 9))
x = sns.heatmap(raw_data.corr(), cmap='coolwarm', square=True, vmax=.9)

# %% [markdown]
# A couple of strong correlations appear here.  Firstly, OverallQual is strongly correlated with SalePrice/logSalePrice.  OverallQual is a subjective variable that could probably be substituted for SalePrice, but it's a feature we are not interested in predicting so we'll drop this variable.  We will also drop 'Id' because it provides no value.
#
# TotRmsAbvGrd and GrLivArea are strongly correlated and GarageCars and GarageArea are strongly correlated.  One of the assumptions of linear regression is the absence of multicollinearity in a dataset of independent variables.  Therefore I will keep the variable between these that is more strongly correlated with logSalePrice

# %%
raw_data = raw_data.drop(columns=['OverallQual', 'Id'])

# %%
raw_data[['logSalePrice','TotRmsAbvGrd', 'GrLivArea', 'GarageCars', 'GarageArea']].corr()
# Out:
#               logSalePrice  TotRmsAbvGrd  GrLivArea  GarageCars  GarageArea
# logSalePrice      1.000000      0.534422   0.700927    0.680625    0.650888
# TotRmsAbvGrd      0.534422      1.000000   0.825489    0.362289    0.337822
# GrLivArea         0.700927      0.825489   1.000000    0.467247    0.468997
# GarageCars        0.680625      0.362289   0.467247    1.000000    0.882475
# GarageArea        0.650888      0.337822   0.468997    0.882475    1.000000

# %% [markdown]
# GrLivArea is more correlated with SalePrice than TotRmsAbvGrd and GarageCars is more correlated with logSalePrice than GarageArea.

# %%
#Dropping TotRmsAbvGrd and GarageArea
raw_data = raw_data.drop(columns=['TotRmsAbvGrd', 'GarageArea'])

# %% [markdown]
# Next, I like to make a number of scatter plots to look at any potential outliers and why they may or may not need to be addressed.  When questions come up later in my analysis I can refer to these plots as well.

# %%
for i in list(raw_data.columns):
    sns.scatterplot(x=raw_data[i], y=raw_data['logSalePrice'])
    plt.show()

# %%
sns.scatterplot(x=raw_data['1stFlrSF'], y=raw_data['logSalePrice'])
plt.show()

# %%
sns.scatterplot(x=raw_data['TotalBsmtSF'], y=raw_data['logSalePrice'])
plt.show()

# %% [markdown]
# There are some outliers, but not too many.  For example on the 1stFlrSF and the Total BsmtSF plots there is one point far off to the right, indicating much larger area at much less of a price.  For now we will keep this outlier, because it may be explained by a ranch-style one floor house or something similar.

# %% [markdown]
# Checking our null values, I'll plot the total missing values per feature and also the percent missing from the dataframe before checking the metadata for some direction on how to address the null values on a feature to feature basis.

# %%
#Creating two DataFrames, one showing the number of null values ordered, the other showing null % ordered--- Then combined into
#one dataframe
data = pd.DataFrame(data=raw_data.isnull().sum(), columns=['Total']).sort_values(by=['Total'], ascending=False)
data2 = pd.DataFrame(data=(raw_data.isnull().sum())/raw_data.shape[0], columns=['Percent']).sort_values(by=['Percent'], ascending=False)
data = pd.concat([data, data2], axis=1)
data[:19]
# Out:
#               Total   Percent
# PoolQC         1453  0.995205
# MiscFeature    1406  0.963014
# Alley          1369  0.937671
# Fence          1179  0.807534
# FireplaceQu     690  0.472603
# LotFrontage     259  0.177397
# GarageType       81  0.055479
# GarageYrBlt      81  0.055479
# GarageFinish     81  0.055479
# GarageCond       81  0.055479
# GarageQual       81  0.055479
# BsmtFinType2     38  0.026027
# BsmtExposure     38  0.026027
# BsmtQual         37  0.025342
# BsmtCond         37  0.025342
# BsmtFinType1     37  0.025342
# MasVnrType        8  0.005479
# MasVnrArea        8  0.005479
# Electrical        1  0.000685

# %% [markdown]
# PoolQC has 99% missing values, so dropping it and keeping PoolArea would be beneficial.  After looking at PoolArea vs SalePrice however, there is no linear relationship and 99% of the houses do not have pools.  We'll drop both PoolArea and PoolQC.
#
# MiscFeature, Alley, Fence, and FireplaceQu all have greater than 48% missing values, but this is because these houses don't have those features according to the metadata.  I'll replace the NaN with a None value.

# %%
raw_data = raw_data.drop(columns=['PoolArea', 'PoolQC'])

# %%
raw_data[['MiscFeature', 'Alley', 'Fence', 'FireplaceQu']] = raw_data[['MiscFeature', 'Alley', 'Fence', 'FireplaceQu']].fillna('None')

# %% [markdown]
# LotFrontage is missing significant data as well, but it cannot be explained in the metadata.  So we can either remove the NaN rows, remove the LotFrontage column, or fill the NaN values.  LotFrontage has linear relationship with logSalePrice so we will try to minimize data loss.
#
# We can replace the NaN values with an average of LotFrontage of some other houses.  Getting even more precise, we can take the average of houses in the same neighborhood.

# %%
raw_data.groupby(['Neighborhood'])['LotFrontage'].mean()
# Out:
# Neighborhood
# Blmngtn    47.142857
# Blueste    24.000000
# BrDale     21.562500
# BrkSide    57.509804
# ClearCr    83.461538
# CollgCr    71.682540
# Crawfor    71.804878
# Edwards    68.217391
# Gilbert    79.877551
# IDOTRR     62.500000
# MeadowV    27.800000
# Mitchel    70.083333
# NAmes      76.462366
# NPkVill    32.285714
# NWAmes     81.288889
# NoRidge    91.878788
# NridgHt    81.881579
# OldTown    62.788991
# SWISU      58.913043
# Sawyer     74.437500
# SawyerW    71.500000
# Somerst    64.666667
# StoneBr    62.700000
# Timber     80.133333
# Veenker    59.714286
# Name: LotFrontage, dtype: float64

# %%
raw_data['LotFrontage'] = raw_data.groupby(['Neighborhood'])['LotFrontage'].apply(lambda x: x.fillna(x.mean()))

# %% [markdown]
# Next filling NaN for ['GarageType', 'GarageQual', 'GarageCond', 'GarageFinish'] with None because that is how its listed in the metadata.

# %%
raw_data[['GarageType', 'GarageQual', 'GarageCond', 'GarageFinish', 'GarageYrBlt']] = raw_data[['GarageType', 'GarageQual', 'GarageCond', 'GarageFinish', 'GarageYrBlt']].fillna('None')

# %% [markdown]
# Next filling NaN for ['BsmtFinType2', 'BsmtExposure', 'BsmtQual', 'BsmtCond', 'BsmtQual', 'BsmtFinType1'] with None because that is how its listed in the metadata.

# %%
raw_data[['BsmtFinType2', 'BsmtExposure', 'BsmtQual', 'BsmtCond', 'BsmtQual', 'BsmtFinType1']] = raw_data[['BsmtFinType2', 'BsmtExposure', 'BsmtQual', 'BsmtCond', 'BsmtQual', 'BsmtFinType1']].fillna('None')

# %% [markdown]
# Next because there are 8 ['MasVnrType', 'MasVnrArea', 'Electrical'] that are missing that cannot be explained in the metadata.  Because these are categorical I cannot replace them with a logical mean or number and because there are only 9 data points I will drop these points.

# %%
#Quick check that our dataframe is where it needs to be
data = pd.DataFrame(data=raw_data.isnull().sum(), columns=['Total']).sort_values(by=['Total'], ascending=False)
data2 = pd.DataFrame(data=(raw_data.isnull().sum())/raw_data.shape[0], columns=['Percent']).sort_values(by=['Percent'], ascending=False)
data = pd.concat([data, data2], axis=1)
data[:19]
# Out:
#               Total   Percent
# MasVnrType        8  0.005479
# MasVnrArea        8  0.005479
# Electrical        1  0.000685
# BedroomAbvGr      0  0.000000
# FireplaceQu       0  0.000000
# Fireplaces        0  0.000000
# Functional        0  0.000000
# KitchenQual       0  0.000000
# KitchenAbvGr      0  0.000000
# HalfBath          0  0.000000
# GarageYrBlt       0  0.000000
# FullBath          0  0.000000
# BsmtHalfBath      0  0.000000
# BsmtFullBath      0  0.000000
# GrLivArea         0  0.000000
# LowQualFinSF      0  0.000000
# 2ndFlrSF          0  0.000000
# 1stFlrSF          0  0.000000
# GarageType        0  0.000000

# %%
raw_data.dropna(axis=0, inplace=True)

# %% [markdown]
# Now that the null values are dealt with, we'll convert all continuous data to float64 and put them in a seperate dataframe that I will concatenate later.

# %% [markdown]
# Looking over the metadata we have some features that are more like categorical features such as ['OverallCond', 'MSSubClass', 'BedroomAbvGr', 'KitchenAbvGr', 'Fireplaces', 'GarageCars'].
#
# ['GarageYrBlt', 'YearBuilt', 'YearRemodAdd', 'MoSold', 'YrSold'] are time series features currently saved as floats.  Because time series can get tricky, for our purposes we will treat these as categorical.
#
# Linear models cannot handle categorical data.  Luckily, pandas has the nifty pandas.get_dummies() function that will convert categorical data to a series of binary 1s, and 0s, that can be fed into a linear model.

# %%
a=[]
for i in raw_data:
    if raw_data[i].dtype == 'object':
        a.append(i)
        
dummy_df = raw_data[a]

# %%
categ = raw_data[['OverallCond', 'MSSubClass', 'BedroomAbvGr', 'KitchenAbvGr', 'Fireplaces', 'GarageCars',
                 'GarageYrBlt', 'YearBuilt', 'YearRemodAdd', 'MoSold', 'YrSold']].astype(object)

# %%
dummy_df = pd.concat([dummy_df, categ], axis=1)

# %%
raw_data = raw_data.drop(columns=['OverallCond', 'MSSubClass', 'BedroomAbvGr', 'KitchenAbvGr', 'Fireplaces', 'GarageCars',
                                 'GarageYrBlt', 'YearBuilt', 'YearRemodAdd', 'MoSold', 'YrSold'])

# %%
dummy_df = pd.get_dummies(dummy_df)

# %%
d=[]
for i in raw_data:
    if raw_data[i].dtype == ('int64'):
        d.append(i)
    elif raw_data[i].dtype == ('float64'):
        d.append(i)

numbers = raw_data[d]

numbers = numbers.astype(float)

# %%
df.shape
# Out:
# (1451, 716)

# %%
df = pd.concat([numbers, dummy_df], axis=1)

# %% [markdown]
# Now that we have our dataframe cleaned and categorical variables in binary we are ready to model.

# %%
# Setting the X_train and Y_train
X_train = df.drop(columns=['SalePrice', 'logSalePrice'])
Y_train = df['logSalePrice']

# %%
from sklearn.model_selection import cross_val_score
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
#setting up training and test groups for evaluation
X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train, test_size=0.3)

# %%
#setting up normalized training group and scaled testing group to evaluate if normalized data will increase accuracy.
from sklearn.preprocessing import normalize, scale

normalize_X = normalize(X_train)

scale_X = scale(X_train)

# %% [markdown]
# Seeing which algorithm works best with the data:

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(n_estimators=100)

rfr.fit(X_train, Y_train)

print('Random Forest Regressor R^2 score of:', rfr.score(X_train, Y_train))
# Out:
# Random Forest Regressor R^2 score of: 0.9793731046786877

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor()

gbr.fit(X_train, Y_train)

print('Gradient Boosting Regressor R^2 score of:', gbr.score(X_train, Y_train))
# Out:
# Gradient Boosting Regressor R^2 score of: 0.9600450490306686

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=.001, max_iter=1000)

ridge.fit(X_train, Y_train)

print('Ridge Regression R^2 score of:', ridge.score(X_train, Y_train))
# Out:
# Ridge Regression R^2 score of: 0.9678883459616402

# %%
from sklearn.linear_model import Lasso
lasso = Lasso(alpha=1, max_iter=10000)

lasso.fit(X_train, Y_train)

print('Lasso Regression R^2 score of:', lasso.score(X_train, Y_train))
# Out:
# Lasso Regression R^2 score of: 0.7015305649453626

# %%
#Testing the best perfomer, Random Forest Regressor
print(cross_val_score(rfr, X_train, Y_train, cv=5))
# Out:
# [0.87044496 0.83488982 0.81502147 0.84754833 0.84232019]

# %% [markdown]
# The Random Forest Regressor performed the best so we will use this model to validate.  The Cross-Validation scores showed high accuracy and precision.  Will test whether normalized/scaled continous data helps prediction.

# %%
print('Random Forest Scores:')

print('Random Forest Regressor R^2 score of non-normalized X_train:', rfr.score(X_train, Y_train))

rfr.fit(normalize_X, Y_train)

print('Random Forest Regressor R^2 score of normalized X_train:', rfr.score(normalize_X, Y_train))

rfr.fit(scale_X, Y_train)

print('Random Forest Regressor R^2 score of scaled X_train:', rfr.score(scale_X, Y_train))
# Out:
# Random Forest Scores:
# Random Forest Regressor R^2 score of non-normalized X_train: 0.9793731046786877
# Random Forest Regressor R^2 score of normalized X_train: 0.9734321920342355
# Random Forest Regressor R^2 score of scaled X_train: 0.9782290599324054

# %% [markdown]
# The normalized data performs worse than the others.  The non-normalized data and the scaled X_train perform about the same, and because of this we will model with the non-normalized data.  Now we'll check the explained variance and the R^2 score between the Y_pred and Y_test labels.

# %%
rfr.fit(X_train, Y_train)
Y_pred = rfr.predict(X_test)

print('Explained variance between Y_pred and Y_test:',metrics.explained_variance_score(Y_test, Y_pred))
print('R^2 score between Y_pred and Y_test:', metrics.r2_score(Y_test, Y_pred))
print('Root mean squared error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print('Mean absolute error:', metrics.mean_absolute_error(Y_test, Y_pred))
print('Relative error %:', (np.mean(np.abs((Y_test-Y_pred)/Y_test))*100))
print('Y_test and Y_pred Correlation %:', stats.pearsonr(Y_test, Y_pred)[0]*100)
# Out:
# Explained variance between Y_pred and Y_test: 0.8476308955505001
# R^2 score between Y_pred and Y_test: 0.8475780961325923
# Root mean squared error: 0.15435234729739425
# Mean absolute error: 0.10533341341497533
# Relative error %: 0.8829444888289276
# Y_test and Y_pred Correlation %: 92.16444646413113

# %% [markdown]
# ### Summary:
#
# * 85.9% of the variability in the test data can be explained by our model.
# * Our Pearson R correlation coefficient of 0.928 shows a strong positive correlation between Y_test and Y_pred.

# %% [markdown]
# ## Considerations for model improvement:
# * I could try to transform some of the continuous data to have an even more linear relationship to logSalePrice which may improve performance.
# * Random Forest deals with collinearity well, so maybe could include some features I deleted too
# * Increased feature engineering for more explanatory features - for example I could try to combine each floors square footage for a new total_square_footage feature.
# * Could go in and try to elimate some of the outliers mentioned.
# * Could try to implement time series analysis
# * Other features particular features about the national economy - perhaps incorporating the DOW, or national GDP.  Could potentiallly code in natioal or regional opinions about the economy to gauge buyer behavior and hence, demand.
# * More data, this dataset only had about 1400 datapoints.
#
# ## Limitations:
# * Model did not use time series.
# * Getting all of these features may not be efficient.  A model that can predict well but with less features may be more practical.
# * This data set is compiled from the city of Ames, Iowa.  The insights provided may not apply to other housing markets.
#
# ## Acknowledgements:
# The Ames Housing dataset was compiled by Dean De Cock for use in data science education, and hosted on kaggle.com.

# %% [markdown]
# ## Notes / Suggestions:
